# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import random
import re
import string
from tqdm import tqdm_notebook
from pandas_summary import DataFrameSummary
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report, f1_score, auc as sk_auc, roc_curve, precision_score, recall_score

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

pd.options.display.max_colwidth = 300
pd.options.display.max_columns = 30
pd.options.display.max_rows = 5000
seed = 42
np.random.seed(seed)

# %% [markdown]
# # Constants

# %%
# Target column name
TARGET_COLUMN = 'ProductCategoryLevel3UNSPSCCode'
data_path = '../data/'

SCENARIO2 = False
SCENARIO3 = True
GET_BUSINESS_CODE = True
if SCENARIO2 + SCENARIO3 != 1:
    raise Exception('Exactly one scenario should be selected')

# %% [markdown]
# # DIFI_CONTENT FILE: Catalog data

# %%
df_raw = pd.read_csv(data_path + 'DIFI_Content_201811030832.csv', sep=';', encoding='latin1')
# Out:
# C:\Users\BJOVAS\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (1,3,7,8,10,12,13,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_raw.sample(20).loc[:, ['BuyerOrgLevel2', 'VendorName']]
# Out:
#                           BuyerOrgLevel2          VendorName
# 2236163                     Øyer kommune     Elkjøp Norge AS
# 3240452                     Øyer kommune  BS Undervisning AS
# 2635137                Haugesund kommune  BS Undervisning AS
# 2756578                Randaberg kommune  BS Undervisning AS
# 3294323              Lillehammer kommune  BS Undervisning AS
# 687065                        Ås kommune  BS Undervisning AS
# 2973571                   Tysvær kommune  BS Undervisning AS
# 533654                    Røyken kommune  BS Undervisning AS
# 4725162                       Ås kommune      HEIDENREICH AS
# 2019680              Lillehammer kommune    Culina / Enor AS
# 5078006                     Øyer kommune          Lekolar AS
# 3150892  Øvre Romerike innkjøpssamarbeid  BS Undervisning AS
# 779503            Akershus fylkeskommune        NorEngros AS
# 1893368  Øvre Romerike innkjøpssamarbeid        NorEngros AS
# 3452339  Øvre Romerike innkjøpssamarbeid          Onninen AS
# 2126143                  Drammen kommune  ASKO/NorgesGruppen
# 58386                      Askøy kommune  BS Undervisning AS
# 2854167                   Rindal kommune  BS Undervisning AS
# 1138255  Øvre Romerike innkjøpssamarbeid          Onninen AS
# 892904                    Larvik kommune        NorEngros AS

# %%
sumdf = DataFrameSummary(df_raw).summary()
sumdf
# Out:
#              ProductCategoryLevel3UNSPSCCode ProductCategoryLevel3Name  \
# count                            4.14819e+06                       NaN
# mean                             4.90364e+07                       NaN
# std                              1.01929e+07                       NaN
# min                              1.01015e+07                       NaN
# 25%                               4.4102e+07                       NaN
# 50%                              5.51015e+07                       NaN
# 75%                              5.51015e+07                       NaN
# max                              9.51416e+07                       NaN
# counts                               4148190                   4148190
# uniques                                 1073                      1132
# missing                              1342617                   1342617
# missing_perc                          24.45%                    24.45%
# types                                numeric               categorical
#
#              ProductCategoryLevel4UNSPSCCode ProductCategoryLevel4Name  \
# count                            4.14819e+06                       NaN
# mean                             4.90364e+07                       NaN
# std                              1.01929e+07                       NaN
# min                              1.01015e+07                       NaN
# 25%                               4.4102e+07                       NaN
# 50%                              5.51015e+07                       NaN
# 75%                              5.51015e+07                       NaN
# max                              9.51416e+07                       NaN
# counts                               4148190                   4148190
# uniques                                 5060                      5274
# missing                              1342617                   1342617
# missing_perc                          24.45%                    24.45%
# types                                numeric               categorical
#
#              BuyerOrgLevel1 BuyerOrgLevel2   VendorName     VendorId  \
# count                   NaN            NaN          NaN          NaN
# mean                    NaN            NaN          NaN          NaN
# std                     NaN            NaN          NaN          NaN
# min                     NaN            NaN          NaN          NaN
# 25%                     NaN            NaN          NaN          NaN
# 50%                     NaN            NaN          NaN          NaN
# 75%                     NaN            NaN          NaN          NaN
# max                     NaN            NaN          NaN          NaN
# counts              5490807        5490807      5490807      4477613
# uniques                   3             84         1049         1227
# missing                   0              0            0      1013194
# missing_perc             0%             0%           0%       18.45%
# types           categorical    categorical  categorical  categorical
#
#                VendorTPID  CatalogueID     Contract      Product  \
# count                 NaN          NaN          NaN          NaN
# mean                  NaN          NaN          NaN          NaN
# std                   NaN          NaN          NaN          NaN
# min                   NaN          NaN          NaN          NaN
# 25%                   NaN          NaN          NaN          NaN
# 50%                   NaN          NaN          NaN          NaN
# 75%                   NaN          NaN          NaN          NaN
# max                   NaN          NaN          NaN          NaN
# counts            3952174      5490807      1902992      5490782
# uniques               272         1709          616      1289932
# missing           1538633            0      3587815           25
# missing_perc       28.02%           0%       65.34%        0.00%
# types         categorical  categorical  categorical  categorical
#
#              VendorPartNumber ClassificationCode ClassificationName  \
# count                     NaN                NaN                NaN
# mean                      NaN                NaN                NaN
# std                       NaN                NaN                NaN
# min                       NaN                NaN                NaN
# 25%                       NaN                NaN                NaN
# 50%                       NaN                NaN                NaN
# 75%                       NaN                NaN                NaN
# max                       NaN                NaN                NaN
# counts                5490807             411888            5490807
# uniques               1107843                153                154
# missing                     0            5078919                  0
# missing_perc               0%             92.50%                 0%
# types             categorical        categorical        categorical
#
#              UnitOfMeasure ContentUnitsPerUnit Manufacturer  \
# count                  NaN                 NaN          NaN
# mean                   NaN                 NaN          NaN
# std                    NaN                 NaN          NaN
# min                    NaN                 NaN          NaN
# 25%                    NaN                 NaN          NaN
# 50%                    NaN                 NaN          NaN
# 75%                    NaN                 NaN          NaN
# max                    NaN                 NaN          NaN
# counts             5470618             1553475      3725658
# uniques                 59               14620        10720
# missing              20189             3937332      1765149
# missing_perc         0.37%              71.71%       32.15%
# types          categorical         categorical  categorical
#
#              ManufacturerProductNo    UnitPrice Currency  \
# count                          NaN          NaN      NaN
# mean                           NaN          NaN      NaN
# std                            NaN          NaN      NaN
# min                            NaN          NaN      NaN
# 25%                            NaN          NaN      NaN
# 50%                            NaN          NaN      NaN
# 75%                            NaN          NaN      NaN
# max                            NaN          NaN      NaN
# counts                     3263309      5490807  5490807
# uniques                     550319       276991        2
# missing                    2227498            0        0
# missing_perc                40.57%           0%       0%
# types                  categorical  categorical     bool
#
#              CatalogLastModifiedYear
# count                            NaN
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN
# counts                       5356758
# uniques                         1272
# missing                       134049
# missing_perc                   2.44%
# types                    categorical

# %% [markdown]
# # Drop rows with missing code or description

# %%
df = df_raw.dropna(subset=[TARGET_COLUMN, 'Product'])
df.reset_index(inplace=True, drop=True)
df.shape
# Out:
# (4148165, 22)

# %% [markdown]
# ## Drop rows where the product description is just a number

# %%
num_pattern = r'^[0-9]*((\.|\,)?[0-9]*)*$'
is_not_num = []
for product_name in df['Product'].values:
    m = re.match(num_pattern, product_name)
    is_not_num.append(not bool(m))
df = df.loc[is_not_num]
df.shape
# Out:
# (4148052, 22)

# %% [markdown]
# ## Get level 3 code by integer division with 100. Drop unused columns

# %%
df['Label'] = df[TARGET_COLUMN].astype('int32')//100

# %%
df = df.loc[:, ['Product', 'Label', 'VendorName', 'CatalogueID']]
# Rename Product column to ProductName
df.columns = ['ProductName', 'Label', 'VendorName', 'CatalogueID']

# %%
df['ProductName'].value_counts()
# Out:
# Bibelen : Den heilage skrifta : Det gamle og Det nye testamentet Nynorsk Innbundet                                                                                  636
# Bibelen : Guds ord Bokmål Innbundet                                                                                                                                 553
# Bibelen : Den hellige skrift : Det gamle og Det nye testamentet Bokmål Innbundet                                                                                    526
# Lise lyddempende bord 60x60cm, H:                                                                                                                                   414
# Nora lyddempende bord 180x80cm, H:                                                                                                                                  414
# Nora lyddempende bord 120x80cm, H:                                                                                                                                  414
# Bibelen : Den hellige skrift : Det gamle og Det nye testamentes kanoniske bøker Bokmål Innbundet                                                                    358
# Samlede dikt Bokmål Innbundet                                                                                                                                       310
# Laminatbord halvrundt 60x120 cm                                                                                                                                     306
# Laminatbord 120x120cm.                                                                                                                                              306
# Laminatbord 120x60cm.                                                                                                                                               306
# Laminatbord 120x80cm.                                                                                                                                               306
# Laminatbord 140x80cm.                                                                                                                                               306
# Laminatbord halrundt 80x120cm                                                                                                                                       306
# Iris                                                                                                                                                                306
# Laminatbord Ø 120cm.                                                                                                                                                306
# Skrifter i samling Nynorsk Innbundet                                                                                                                                299
# Støydempende bord bøk 1/2 Ø 120 cm.                                                                                                                                 276
# Støydempende bord 120x120cm.                                                                                                                                        276
# Støydempende bord bøk Ø 120cm.                                                                                                                                      276
# Støydempende bord bøk 120x80cm.                                                                                                                                     276
# Støydempende bord halvrund 80x120 cm                                                                                                                                276
# Støydempende bord bøk 140x80cm.                                                                                                                                     276
# Støydempende bord bøk120x60cm.                                                                                                                                      276
# Lise Laminatbord 60x60cm, H:                                                                                                                                        270
# Lise Laminatbord 140x70cm, H:                                                                                                                                       270
# Dikt i samling Nynorsk Innbundet                                                                                                                                    268
# Bibelen Nynorsk Innbundet                                                                                                                                           246
# Bibelen Bokmål Innbundet                                                                                                                                            236
# Titan                                                                                                                                                               216
# Samlede dikt Bokmål Heftet                                                                                                                                          209
# Engangshanske nitril XL upudret blå                                                                                                                                 175
# Norge Bokmål Innbundet                                                                                                                                              168
# Engangshanske nitril M upudret blå                                                                                                                                  161
# Arven Bokmål Heftet                                                                                                                                                 157
# Eventyr Bokmål Innbundet                                                                                                                                            156
# Jungelboken Bokmål Innbundet                                                                                                                                        154
# Markedsføringsledelse Bokmål Heftet                                                                                                                                 151
# Engangshanske nitril L upudret blå                                                                                                                                  144
# London Bokmål Heftet                                                                                                                                                141
# Media i samfunnet Nynorsk Heftet                                                                                                                                    135
# Engangshanske nitril S upudret blå                                                                                                                                  133
# Dikt i samling Nynorsk Heftet                                                                                                                                       129
# Bibelen : Guds ord (bokmål, innbundet)                                                                                                                              128
# Støydempende Bord 120x60 cm.                                                                                                                                        126
# Reisen Bokmål Innbundet                                                                                                                                             126
# Støydempende Org. Bord S-form120x60 cm.                                                                                                                             126
# Støydempende bord Ying/yang 120x80 cm.                                                                                                                              126
# Støydempende bord S-form 120x80 cm.                                                                                                                                 126
# Støydempende Organisk Bord 120x80 cm.                                                                                                                               126
# Støydempende bord Ying/yang 120x60 cm.                                                                                                                              126
# Dikt i utval Nynorsk Innbundet                                                                                                                                      125
# Engangshanske vinyl L upudret klar                                                                                                                                  124
# Studentbibelen : Bibelen - Guds ord Bokmål Innbundet                                                                                                                124
# Farger Bokmål Heftet                                                                                                                                                124
# Engangshanske vinyl M upudret klar                                                                                                                                  124
# Engangshanske vinyl S upudret klar                                                                                                                                  122
# Biler 3 Bokmål Innbundet                                                                                                                                            121
# Norske folkeeventyr Bokmål CD                                                                                                                                       120
# Paris Bokmål Heftet                                                                                                                                                 118
# Universal ProbeLibrary Probes                                                                                                                                       117
# IRIS                                                                                                                                                                117
# Hverdagsbibelen pluss Bokmål Innbundet                                                                                                                              116
# Roma Bokmål Heftet                                                                                                                                                  115
# Sagalitteraturen Nynorsk Innbundet                                                                                                                                  115
# Electronic HP Care Pack 4-Hour Same Business Day Hardware Support Post Warranty - Utvidet serviceavtale - deler og arbeid - 1 år - på stedet - 13X5 - 4 t - for     114
# Atea Service Pack 1 - Same Day Shipment                                                                                                                             113
# New York Bokmål Heftet                                                                                                                                              113
# Hevnen Bokmål Heftet                                                                                                                                                111
# Amsterdam Bokmål Heftet                                                                                                                                             110
# Kosmos YF : arbeidsbok : naturfag for yrkesfaglege utdanningsprogram Nynorsk Heftet                                                                                 108
# Fortellinger Bokmål Innbundet                                                                                                                                       108
# Juss 1 : rettslære 1 for videregående skole Bokmål Heftet                                                                                                           108
# Organisasjon og ledelse Bokmål Heftet                                                                                                                               108
# Rettskildelære Bokmål Innbundet                                                                                                                                     107
# Teknisk termodynamikk med strømningslære Bokmål Heftet                                                                                                              107
# Sosialpsykologi Bokmål Heftet                                                                                                                                       106
# Decoupagepapir, ark 25x35 cm, 17 g, 10 ark                                                                                                                          106
# Bibelen : Den heilage skrifta : dei kanoniske skriftene i Det gamle og Det nye testamentet Nynorsk Innbundet                                                        105
# Italiensk grammatikk Bokmål Heftet                                                                                                                                  105
# Norsk ordbok : band 2. Ordbok over det norske folkemålet og det nynorske skriftmålet Nynorsk Heftet                                                                 105
# Obligasjonsrett Bokmål Innbundet                                                                                                                                    104
# Juridiske dokumenter og formularer : praktisk oppslagsbok med kommentarer Bokmål Heftet                                                                             103
# Effektiv bekjempelse av maur Bokmål Heftet                                                                                                                          103
# Øya Bokmål Innbundet                                                                                                                                                102
# VERNESKOLETT ALBA&N BYGDIN G1084CK S3 SRC HRO                                                                                                                       102
# VERNESKO ALBA&N GAUSTA C04S S3 SRC                                                                                                                                  102
# Norske folkeeventyr Bokmål Innbundet                                                                                                                                102
# Kokkejakke unisex langt erme, sateng, unisex                                                                                                                        102
# JALAS VERNESTØVLETT OFFROAD+ S3 SRC CI HRO                                                                                                                          102
# JALAS VERNESKO TERRA S3 SRC CI HRO                                                                                                                                  102
# Alice i Eventyrland Bokmål Innbundet                                                                                                                                102
# VERNESKOLETT ALBA&N DOVRE C06S S3 SRC                                                                                                                               102
# VERNESTØVLETT ALBA&N ØYEREN G31K S3 SRC HRO                                                                                                                         102
# Askepott Bokmål Innbundet                                                                                                                                           102
# VERNESKO ALBA&N BANDAK G1096K S3 SRC HRO                                                                                                                            102
# Mikrofibermopp 60cm tørr/fukt                                                                                                                                       101
# Engangshanske nitril L upudret hvit                                                                                                                                 101
# Selskapsrett Bokmål Innbundet                                                                                                                                       101
# Norske folkeeventyr : det var engang : tospråklig eventyrbok Bokmål Innbundet                                                                                       100
# Norske folkeeventyr : det var eingong : tospråkleg eventyrbok Nynorsk Innbundet                                                                                     100
# Tekst i tid og rom : norsk språkhistorie Nynorsk Heftet                                                                                                             100
# Den engelske kanal Bokmål Heftet                                                                                                                                    100
# Engangshanske latex S upudret klar                                                                                                                                  100
# Tall Bokmål Heftet                                                                                                                                                   99
# Vaiana Bokmål Innbundet                                                                                                                                              98
# Engangshanske latex L upudret klar                                                                                                                                   97
# NORA VERNEGUMMISTØVEL MULTIJAN GRØNN S4                                                                                                                              97
# Engangshanske nitril M upudret hvit                                                                                                                                  96
# VERNESKO ATLAS XP 205 S1P SRC ESD SVART/BLÅ                                                                                                                          96
# Berlin Bokmål Heftet                                                                                                                                                 96
# Engangshanske latex M upudret klar                                                                                                                                   95
# Mikrofiberklut 32x32cm rød                                                                                                                                           94
# Dukkevogn                                                                                                                                                            94
# Mikrofiberklut 32x32cm blå                                                                                                                                           94
# Volvo lastvagnar : roman Bokmål Heftet                                                                                                                               92
# Engangshanske nitril S upudret hvit                                                                                                                                  91
# VERNESTØVEL DUNLOP FOODPRO (CA61131) PUROFORT MULTIGRIP HVIT (CA61131) S4 CI SRC                                                                                     91
# ATLAS VERNESKO SL405 XP S1P SRC BLÅ                                                                                                                                  90
# VERNESKO ATLAS SL9205 BOA S1P SRC GRØNN                                                                                                                              90
# VERNEMYKSKO BS MED HÆLREIM SB SRC SVART                                                                                                                              90
# VERNESANDAL ATLAS C265 XP S1P SRC GREEN                                                                                                                              90
# KENTAUR CHINO DAMEBUKSE SVART                                                                                                                                        90
# ATLAS VERNESTØVEL CL826 S2 SRC HVIT                                                                                                                                  90
# VERNESKO ATLAS C205 XP S1P SRC GREEN                                                                                                                                 90
# HANSKE HELFORET MICROTHAN TEGERA PRO GRÅ/SVART                                                                                                                       90
# *VERNESTØVEL DUNLOP PUROFORT+ GUL (C762241) S5 CI SRC                                                                                                                90
# VERNEMOKASIN ATLAS CL490 HVIT S2                                                                                                                                     90
# VERNESKO ATLAS SL9405 BOA S1P SRC BLÅ                                                                                                                                90
# VERNEMYKSKO BS MED VRISTREIM SB SRC SVART                                                                                                                            90
# VERNESTØVLETT ALBA&N FEMUNDEN G1097K ZIP S3 HRO                                                                                                                      90
# VERNEMYKSKO BS MED HÆLREIM SB SRC HVIT                                                                                                                               90
# VERNESKO ATLAS SL 9645 BOA S3 SRC BLÅ                                                                                                                                90
# VERNESKOLETT ATLAS SL9845/20 XP BOA ESD S3 SVART/GRÅ/BLÅ                                                                                                             90
# VERNESKO ATLAS SL 9625 BOA S3 SRC GRØNN                                                                                                                              90
# VERNESANDAL ATLAS SL465 XP S1P SRC BLUE                                                                                                                              90
# Tornerose Bokmål Heftet                                                                                                                                              89
# Beatles Bokmål Heftet                                                                                                                                                88
# Bibelen Nynorsk Heftet                                                                                                                                               88
# Den lille muldvarpen som ville vite hvem som hadde bæsjet på hodet hans Bokmål Innbundet                                                                             87
# Lengsel Bokmål Heftet                                                                                                                                                87
# Barcelona Bokmål Heftet                                                                                                                                              87
# Engangshanske latex XL upudret klar                                                                                                                                  86
# Norwegen Tysk Innbundet                                                                                                                                              86
# Praha Bokmål Heftet                                                                                                                                                  86
# BRASKO VERNEMYKSKO MED HÆLREIM SB E SVART                                                                                                                            85
# JALAS TITAN+ VERNESTØVLER S3 SRC CI HRO                                                                                                                              84
# DAMEBUKSE KENTAUR SVART                                                                                                                                              84
# SIKA VERNEMOKASIN OPTIMAX S2 SRA HVIT                                                                                                                                84
# MONTERINGSHANSKE MICROTHAN TEGERA PRO GRÅ/SVART                                                                                                                      84
# JALAS KING SKAFTESTØVLETT S3 SRC CI HRO SVART                                                                                                                        84
# NORA VERNEGUMMISTØVEL MEGAJAN MED SP.TR. GRØNN S5                                                                                                                    84
# ATLAS STØVLETT SL 9935 XP S3 BOA ESD                                                                                                                                 84
# JALAS VERNESTØVLETT WINTER KING SVART S3 SRC HRO                                                                                                                     84
# JALAS WHITE VERNEMOKASIN S2                                                                                                                                          84
# VERNESKO ALBA&N VIGRA BLÅ S1P SRC                                                                                                                                    84
# JALAS LOW VERNEMOKKASIN S2 SRC HRO CI SORT                                                                                                                           84
# VERNEMOKASIN ATLAS CL178 BOA HVIT S2                                                                                                                                 84
# VERNESTØVLETT ALBA&N FAUSKE SVART S3 SRC                                                                                                                             84
# JALAS VERNESTØVLETT ICETRACK S3 SRC CI HRO                                                                                                                           84
# STIHL COMFORT SAGVERN GUMMISTØVEL SVART/ORANGE                                                                                                                       84
# Oppdrag Dory Bokmål Innbundet                                                                                                                                        83
# Frost Bokmål Innbundet                                                                                                                                               83
# -2146826273                                                                                                                                                          82
# Hevnen Bokmål Innbundet                                                                                                                                              82
# Forstørrelsesglass                                                                                                                                                   82
# Vikingene Bokmål Innbundet                                                                                                                                           82
# Biler Bokmål Innbundet                                                                                                                                               82
# Venner Bokmål Innbundet                                                                                                                                              81
# Stockholm Bokmål Heftet                                                                                                                                              81
# Mattevogn                                                                                                                                                            81
# Askepott Bokmål Heftet                                                                                                                                               81
# Avf.sekk LD 70my gul 72x112cm 100L                                                                                                                                   81
# Venezia Bokmål Heftet                                                                                                                                                80
# Det nye testamente og Salmenes bok Bokmål Innbundet                                                                                                                  80
# Engangshanske vinyl XL upudret klar                                                                                                                                  80
# Engangshanske nitril L upudret lang blå                                                                                                                              80
# Mine første ord Bokmål Heftet                                                                                                                                        80
# Nemesis Bokmål Heftet                                                                                                                                                80
# Min historie Bokmål Innbundet                                                                                                                                        80
# Jernvognen Bokmål Heftet                                                                                                                                             80
# Ildprøven Bokmål Innbundet                                                                                                                                           80
# Engangshanske nitril M upudret lang blå                                                                                                                              79
# VERNESTØVEL DUNLOP PUROFORT PROF. GRØNN (C462933) S5 CI SRA                                                                                                          79
# Terje Vigen Bokmål Innbundet                                                                                                                                         79
# Flukten Bokmål Innbundet                                                                                                                                             79
# Dikt Bokmål Heftet                                                                                                                                                   79
# Sviket Bokmål Heftet                                                                                                                                                 79
# Segl : katolsk årsskrift for religion og samfunn Bokmål/nynorsk Heftet                                                                                               79
# Balansebrett                                                                                                                                                         79
# Arven Bokmål Innbundet                                                                                                                                               79
# Utvalgte dikt Bokmål Innbundet                                                                                                                                       79
# ATLAS ALU-TEC 165 XP S1P SRC SORT/LIME                                                                                                                               78
# JALAS PRIMA METALLFRI UNIFORMSKO S3 SRC                                                                                                                              78
# ATLAS AB 822 XP S3 SRC                                                                                                                                               78
# Savnet Bokmål Heftet                                                                                                                                                 78
# JALAS VERNESKO ZENIT EASYROLL S3 SRC BOA LUKKESYSTEM                                                                                                                 78
# JALAS EXALTER EASYROLL S3 SRC HRO                                                                                                                                    78
# KOKKEJAKKE HVIT                                                                                                                                                      78
# SIKA VERNEMOKASIN OPTIMAX S2 SRA SVART                                                                                                                               78
# Snorre Sturlasons kongesagaer Bokmål Innbundet                                                                                                                       78
# Fedrenes synder Bokmål Innbundet                                                                                                                                     78
# JALAS PELSFORET VERNESKOLETT TEMPERA S3 SRC                                                                                                                          78
# Linoleumsbord hvitpig.BjerkT-fot80x170cm                                                                                                                             78
# JALAS EXALTER EASYROLL S1 P SRC HRO                                                                                                                                  78
# JALAS VERNESKO ZENIT S3 SRC BOA® LUKKESYSTEM                                                                                                                         78
# VERNESANDAL ATLAS TX 360 S1 SRC SVART                                                                                                                                78
# KENTAUR KOKKEJAKKE 50% BOM/50% POL HVIT                                                                                                                              78
# JALAS VERNESKO EXALTER SVART/RØD S3 SRC HRO                                                                                                                          78
# JALAS BIO METALLFRI VERNESANDAL S1P                                                                                                                                  78
# JALAS VERNESKO S-SPORT S3 SVART/ORANSJE                                                                                                                              78
# HERREBUKSE KENTAUR SVART                                                                                                                                             78
# Servietter, str. 33x33 cm, 20 stk.                                                                                                                                   78
# VERNEMYKSKO BS MED VRISTREIM SB SRC HVIT                                                                                                                             78
# VERNESTØVLETT ATLAS GTX 945 XP S3 CI SRC                                                                                                                             78
# JALAS METALLFRI VERNESKO EKO S3                                                                                                                                      78
# JALAS VERNESANDAL MONZA SPORT S1P                                                                                                                                    78
# Inferno Bokmål Innbundet                                                                                                                                             78
# KOKKEBUKSE UNISEX HVIT/SVART PEPITARUTET                                                                                                                             78
# HERREBUKSE KENTAUR HVIT                                                                                                                                              78
# JALAS ZENIT EASYROLL VERNESTØVLETT MED BOA LÅS OG PELSFOR S3 SRC                                                                                                     78
# Sjalusi Bokmål Heftet                                                                                                                                                78
# JALAS VERNESKO ZENIT S3 SRC                                                                                                                                          78
# Marikken Bokmål Innbundet                                                                                                                                            77
# Let og finn Bokmål Innbundet                                                                                                                                         77
# Ikaros Bokmål Heftet                                                                                                                                                 77
# Harry Potter og mysteriekammeret Bokmål Innbundet                                                                                                                    77
# Harry Potter og fangen fra Azkaban Bokmål Innbundet                                                                                                                  77
# Treningslære 2 : arbeidsbok Bokmål Heftet                                                                                                                            77
# Skjønnheten og udyret Bokmål Innbundet                                                                                                                               77
# Avf.sekk LD 70my rød 72x112cm 100L                                                                                                                                   76
# 101 dalmatinere Bokmål Innbundet                                                                                                                                     76
# Dikt i samling Bokmål Heftet                                                                                                                                         76
# Den siste coyote Bokmål Heftet                                                                                                                                       76
# Lady og Landstrykeren Bokmål Innbundet                                                                                                                               76
# Godnatthistorier Bokmål Innbundet                                                                                                                                    76
# Ronja Røverdatter Bokmål Innbundet                                                                                                                                   75
# Blodets bånd Bokmål Heftet                                                                                                                                           75
# Mine 100 første ord Bokmål Heftet                                                                                                                                    75
# Samfunnsgeografi Bokmål Heftet                                                                                                                                       75
# Nomadens stemme : fabler og eventyr fra Somalifolket Bokmål Innbundet                                                                                                75
# Skrifter i samling Nynorsk Heftet                                                                                                                                    75
# Kosmos påbygging : lærebok : påbygging for generell studiekompetanse i naturfag Nynorsk Heftet                                                                       75
# I gode og onde dager Bokmål Heftet                                                                                                                                   75
# Dødens codex Bokmål Heftet                                                                                                                                           75
# Honningkrukken Bokmål Heftet                                                                                                                                         75
# Datasystem for vidaregåande opplæring Nynorsk Heftet                                                                                                                 74
# Avslørt Bokmål Heftet                                                                                                                                                74
# Øv og les 3 Bokmål Heftet                                                                                                                                            74
# Matematikk 2P Nynorsk Heftet                                                                                                                                         74
# Matematikk 2P Bokmål Heftet                                                                                                                                          74
# Ukas bokstav Bokmål Heftet                                                                                                                                           74
# Dyr Bokmål Heftet                                                                                                                                                    74
# Dinosaurer Bokmål Innbundet                                                                                                                                          74
# Nynorsk som sidemål Nynorsk Heftet                                                                                                                                   74
# Matematikk 1T Bokmål Heftet                                                                                                                                          74
# Barndom Bokmål Heftet                                                                                                                                                74
# Hysj Bokmål Heftet                                                                                                                                                   74
# Grunnleggende regnskap Bokmål Heftet                                                                                                                                 74
# Det nye vannet Bokmål Heftet                                                                                                                                         74
# Peter Pan Bokmål Innbundet                                                                                                                                           74
# Matematikk 1P Bokmål Heftet                                                                                                                                          74
# Øv og les 4 Bokmål Heftet                                                                                                                                            74
# Matematikk 1T Nynorsk Heftet                                                                                                                                         74
# Forbrytelse og straff Bokmål Heftet                                                                                                                                  74
# Mitt liv Bokmål Heftet                                                                                                                                               74
# Vekebokstav Nynorsk Heftet                                                                                                                                           74
# Karius og Baktus Bokmål Innbundet                                                                                                                                    74
# Matematikk 1P Nynorsk Heftet                                                                                                                                         74
# Historie og filosofi 2 Nynorsk Innbundet                                                                                                                             73
# Matematikk R2 Bokmål Heftet                                                                                                                                          73
# Matematikk R2 Nynorsk Heftet                                                                                                                                         73
# Hvite niggere Bokmål Heftet                                                                                                                                          73
# Matematikk S2 Bokmål Heftet                                                                                                                                          73
# Historie og filosofi 1 Nynorsk Innbundet                                                                                                                             73
# Norsk grammatikk Bokmål Heftet                                                                                                                                       73
# Snøbarnet : en roman Bokmål Heftet                                                                                                                                   73
# Matematikk S1 Bokmål Heftet                                                                                                                                          73
# Matematikk R1 Bokmål Heftet                                                                                                                                          73
# Matematikk R1 Nynorsk Heftet                                                                                                                                         73
# Matematikk S1 Nynorsk Heftet                                                                                                                                         73
# Matematikk S2 Nynorsk Heftet                                                                                                                                         73
# Visning Bokmål Heftet                                                                                                                                                73
# Økonomistyring Bokmål Heftet                                                                                                                                         73
# Bjørne benk 6 rom B:160,5 cm H:31,5cm                                                                                                                                72
# ...
# HANSKE GUIDE 585 10                                                                                                                                                   1
# Intel Xeon E5-2620 - 2 GHz - 6 kjerner - 12 strenger - 15 MB cache - for ProLiant SL230s Gen8                                                                         1
# Base max-stabil svart venstre XXL                                                                                                                                     1
# Skillekort A4 5delt natur kartong                                                                                                                                     1
# Lexmark Card for IPDS and SCS/TNe - ROM (sidebeskrivelsesspråk) - IBM IPDS/AFP, SCS/TNe, TCP/IP capability, SCS (LU1) - for X466de, 466dte, 466dwe                    1
# PK20 PILOT G2 GELPENN FINE SORT                                                                                                                                       1
# BUNTBÅND L=450MM B=7,6MMT120M                                                                                                                                         1
# STIKKSAGBL T144DP 74MM A5 TRE                                                                                                                                         1
# A2-0,6 FE-45 D, SN FE TELEKABEL                                                                                                                                       1
# IT 2 :programmering i Actionscript 3.0 :Flash CS5 professional Bokmål Heftet                                                                                          1
# Bibelen i brennpunktet :for tro, historie og litteratur Bokmål Heftet                                                                                                 1
# REKKEKLEMME D4/6.N,2L 1SNA290063R0100 ABB                                                                                                                             1
# Moppeholder jonmaster ultra wing                                                                                                                                      1
# Philips Brilliance 220X1SW - LCD-skjerm - 22" - 1680 x 1050 - 300 cd/m2 - 1000:1 - 12000:1 (dynamisk) - 2 ms - DVI-D, VGA                                             1
# INST.KAB CAT,7 PIMF4X2XAWG24/7 CC TELEKABEL                                                                                                                           1
# StandUp matte / SvartSvart                                                                                                                                            1
# FRONTPL. FOR DMB 300 P                                                                                                                                                1
# TRESKR 5.0X100 A4 SH TX25 TRESKRUE SYREFAST SENKHODE AN                                                                                                               1
# Led retro classic a60 e27 fil                                                                                                                                         1
# Treskr 3.0X35 EZ SH PZ ETA treskrue elzink senkhode SPAX                                                                                                              1
# Skjæremaskin Fellowes A3 Giljotin plasma                                                                                                                              1
# Bukse 3223 mgrå/sor 100 snic                                                                                                                                          1
# EXPANDER SORMAT S-KA FZB 16/5X123 1/FRP ETA-08/0173                                                                                                                   1
# MSDL0-T641_5.0-S04                                                                                                                                                    1
# LED DOWNLIGHT CURION 185 HV-IC 230V 14W 1250Lm 2700K cs HVIT Illuxtron                                                                                                1
# Kopipapir STAPLES Copy A4 80g (500) (Forpakning á 500 stykk)                                                                                                          1
# ROEBUCK-2527070                                                                                                                                                       1
# APC Smart-UPS XL Modular 3000VA - UPS - AC 230 V - 2.85 kW - 3000 VA - 2U                                                                                             1
# Maskinskr 4X50 EZ PZ D7985 4.8 elforzinket panhode Pozi                                                                                                               1
# Glidelåspose grippie 120x180mm 50my pose á 100 stk                                                                                                                    1
# Termorull 80xØ80x12,7mm 74m kassarull                                                                                                                                 1
# F-10 FROSTVAKT 220W 22M M/PLUG - FROSTBESKYTTELSE AV RØR                                                                                                              1
# G3 SLIM WHITE EXTRA STRONG PSWL 21,6G 5,00 Eske x 21,6g - Bestilles i Eske                                                                                            1
# UPER.RENNE W1/40-100 L=2M .FZS                                                                                                                                        1
# OMSLAG LYRECO MANILLA A4 31,5 X 23,5 CM GUL PK100                                                                                                                     1
# H07RN-F 750V 4G4mm²                                                                                                                                                   1
# SØYLEBOREMASKIN GIR DREVET S-35 Type S-35CE                                                                                                                           1
# TILFØRSELSLEDNING 5-POL, 4,5M TEHALIT                                                                                                                                 1
# NESQUIK 1KG                                                                                                                                                           1
# Marker COPIC dobbelspiss / RødRød                                                                                                                                     1
# Høytrykksnatriumlamper HST 400W HIGH OUTPUT E40 (Std. Pakning-10 stk)                                                                                                 1
# Regler for passasjer og lasteskip m.v. 2013 :bok og CD-ROM Bokmål Heftet                                                                                              1
# gamma-[(6-Aminohexyl)imido]-ATP - Texas Red,120µl(1 mM)                                                                                                               1
# Fugeskum sikabond foamfix 750 ml                                                                                                                                      1
# PENSEL FLAT PERFECT UTE 75MM JORDAN                                                                                                                                   1
# Tung plate lys beige laminat 2000 x 620 x 40                                                                                                                          1
# KULEGAFFEL 16MM 4217,23/1                                                                                                                                             1
# KONTAKTOR 25A, 3P, AC LC1D253E7 SCHNEIDER                                                                                                                             1
# formline lasurmaling 500 ml. Oransje.                                                                                                                                 1
# Certified Biomek Type Filter Pipette Tip 1-50µl 96 Rack/ST Natural,960                                                                                                1
# Urinpose, lukket sengepose Unomedical A2 1,5L A2 sl=110cm 100 Stykk                                                                                                   1
# VINYL TAPE 6,1MMX6,09M KONT.                                                                                                                                          1
# Lasertoner hp c9733a color laserjet 5500 magenta                                                                                                                      1
# PÅVEGGLOKK 2 HULL TETT PH                                                                                                                                             1
# LYSRØR L 36W/66 GRØNN628                                                                                                                                              1
# tert-Butyl methyl ether, for GC residue analysis,1 l                                                                                                                  1
# CLAUDE VAL ROSE 13% CLAUDE-VAL                                                                                                                                        1
# ELEMENTAUT.16A C 2P DC                                                                                                                                                1
# Bind Tena for Men Level 2 Tena for Men (Pose á 20 stykk)                                                                                                              1
# Optiplast C brun 6cmx2,5m bomull                                                                                                                                      1
# FRIFELT MODUL 2X4 MODUL                                                                                                                                               1
# Tosidig tape 4970 hvit 50mmx50m                                                                                                                                       1
# 85033 ABS BOKS 241X194X105 K                                                                                                                                          1
# Ensom planet Bokmål Innbundet                                                                                                                                         1
# Jul eller aldri! Bokmål Innbundet                                                                                                                                     1
# Kartnål 4x15mm eske à 100 stk. ass. farger                                                                                                                            1
# Rosetta 2 Competent cell Set 1 * 1 items                                                                                                                              1
# LINERGY EV. HZ. Skinne 3200A - 4567                                                                                                                                   1
# ROEBUCK-218046                                                                                                                                                        1
# Transcend - Minne - 1 GB : 2 x 512 MB - DIMM 240-pin - DDR2 - 533 MHz / PC2-4200 - CL4 - 1.8 V - ikke-bufret - ikke-ECC - for P/N: M9590SA/A, M9590X/A, M9590ZH/      1
# INTERPACT INS250 200A 3P                                                                                                                                              1
# Intermec - Håndholdt batteri - for Intermec 700 Color                                                                                                                 1
# Cisco Nexus 2248TP GE Fabric Extender - Utvidelsesmodul - Fast Ethernet, Gigabit Ethernet - 100Base-TX, 1000Base-T - 48 porter + 4 x SFP+ (uplink)                    1
# Tall i arbeid. Lærer : lærernettsted : Matematikk for YF Bokmål Digitalt læremiddel                                                                                   1
# JORDBÆRSYLTETØY LETT 535G ELDORADO                                                                                                                                    1
# AUTOMAT LP2K3 PROS                                                                                                                                                    1
# Klassebiletet :norsk for barnetrinnet Nynorsk Heftet                                                                                                                  1
# BLINDNAGLE 4.8X16ST/ST EL DI                                                                                                                                          1
# Kontaktor 32A 3P 24VAC - LC1D32B7                                                                                                                                     1
# TRESKR. TKFX SPAX-S 4.0X25 EZ 4.0X25 FZB ETA-12/0114                                                                                                                  1
# Msc Reker Pillet 800gr i Map                                                                                                                                          1
# T-PROFIL OMEGA2 T5 HFD 2X14W                                                                                                                                          1
# Canon DCC-90 - Myk veske for digitalt fotokamera - for PowerShot G6, S1 IS, S2 IS, S3 IS, S5 IS                                                                       1
# UNIVERS.Ø12,PNP,NO,KAB.SN=4 XS612B1PAL5 SCHNEIDER                                                                                                                     1
# FLUOROPORE PTFE 3UM 58MM 100PK                                                                                                                                        1
# GENSER COLLEGE SYNL XL ORANSJE                                                                                                                                        1
# FIKEN FERSK STK 16,00 Stk x stk - Bestilles i Stk                                                                                                                     1
# LINDT CREATION PURE CHOCOLATE 150G                                                                                                                                    1
# Fargeblyant Lekolar Fine 12 farger                                                                                                                                    1
# Wyse Thin OS - ( v. 5.0 ) - vedlikehold ( 2 år ) - 1 sete                                                                                                             1
# KONTAKTOR 50A 230V50HZ 240V60 DILM50 230VAC                                                                                                                           1
# Industrivekt 180 kg Oppløsning 200 g                                                                                                                                  1
# Kabel STARTECH.COM 6 FT HDMI TO DVI-                                                                                                                                  1
# Overfl.desinfeksjon LifeClean 1l daglig 1 Stykk                                                                                                                       1
# Name: ProductName, Length: 837526, dtype: int64

# %% [markdown]
# ## Drop duplicates

# %%
if SCENARIO2:
    df.drop_duplicates(inplace = True)
elif SCENARIO3:
    df.drop_duplicates(inplace = True, subset=['ProductName', 'Label'])
df.shape
# Out:
# (880036, 4)

# %%
df['ProductName'].unique().shape
# Out:
# (837526,)

# %% [markdown]
# # Get buisiness domain code

# %% [markdown]
# ## Read data from Brønnøysund register
#
# We only look at the primary business code as most businesses only deal with this

# %%
df_over = pd.read_csv(data_path + 'enheter_alle.csv', delimiter=';', encoding='latin1', dtype={'Næringskode 1': 'str'})
df_under = pd.read_csv(data_path + 'underenheter_alle.csv', delimiter=';', encoding='latin1', dtype={'Næringskode 1': 'str'})
df_over.dropna(subset=['Næringskode 1'], inplace=True)
df_under.dropna(subset=['Næringskode 1'], inplace=True)
# Out:
# C:\Users\BJOVAS\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (9,16,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\BJOVAS\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (9,11,16,18,29,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Create new list of vendor names in  the catalog data and remove any trailing "AS" or "ASA"

# %%
def filter_name(name):
    split = name.split(' ')
    if split[-1] == 'as' or split[-1] == 'asa':
        return ''.join(split[:-1])
    return name

# %%
vendor_names_raw = df['VendorName'].unique()
names_raw = {}
vendor_names = []
for name in vendor_names_raw:
    vendor_name = filter_name(name.lower())
    vendor_names.append(vendor_name)
    names_raw[vendor_name] = name

# %% [markdown]
# ## Start building a map for mapping raw vendor names as they appear in catalog data to business domain codes. Initial map is populated by manually found codes for some of the more frequent names for which we cannot automatically find a code

# %%
#No match
manually_mapped = {'ASKO/NorgesGruppen':'47111', 'LYRECO AS':'46660', 'TOOLS NORGE AS': '46900', 'ELEKTROSKANDIA AS':'46691', 'Staples Norway AS':'46499', 'Av Form AS':'46499', 'Plandent AS (tidligere NDD - AS Norsk Dental Depot':'46460', 'H. I. GIØRTZ SØNNER AS':'46390', 'Albert E. Olsen AS':'46630', 'Culina / Enor AS':'46441', 'Norgesgruppen (Asko)':'47111', 'Cater Drammen AS (a part of Servicegrossistene)':'46390', 'MÅKESTAD ENGROS ØST AS (A PART OF SERVICEGROSSISTENE)':'46390', 'Per Strand Tromsø AS':'46732','Telenor Inpli AS':'62030', 'Norengros Medisinske Forbruksvarer':'46460', 'AH Diagnostics':'46900', 'Odd Langdalen Frukt og Grønt Engros AS':'46310', 'E.A Smith AS':'46739', 'Nordialog':'46520', 'Atea\'\'AS':'46510', 'Tine BA':'10510', 'Tromsø Telecom AS':'71129', 'Radioservice Askøy AS':'47430', 'BIO-RAD LABORATORIES AB NORGE':'46750', 'Apro Tele og Data AS':'46520'}
#Match, but not a valid code
missing_codes = {'Atea AS':'46510', 'CREATIV COMPANY AS':'46499', 'Trigonor as':'46495', 'TINE SA':'10510', 'ITELLO AS':'46510'}
full_map = manually_mapped.copy()
full_map.update(missing_codes)

# %% [markdown]
# ## Add the exact matches between catalog data and register data after applying the same AS/ASA filter to the names in the register data
#
# We have access to both primary units and sub-units of businesses. The sub-unit register is only used if there is no match in the primary unit register

# %%
found = []
missing = []
over = 0
under = 0
over_names = dict([(filter_name(x.lower()), x) for x in df_over['Navn'].values])
under_names = dict([(filter_name(x.lower()), x) for x in df_under['Navn'].values])
for name in tqdm_notebook(vendor_names):
    raw_name = names_raw[name]
    if raw_name not in full_map:
        if name in over_names:
            found.append(name)
            code = df_over[df_over['Navn'] == over_names[name]].loc[:,['Næringskode 1']].values[0,0]
            full_map[raw_name] = ''.join(code.split('.'))
            over += 1
        else:
            if name in under_names:
                found.append(name)
                code = df_under[df_under['Navn'] == under_names[name]].loc[:, ['Næringskode 1']].values[0,0]
                full_map[raw_name] = ''.join(code.split('.'))
                under += 10
            else:
                missing.append(name)
# Out:
# HBox(children=(IntProgress(value=0, max=379), HTML(value='')))

# %%
len(full_map)
# Out:
# 231

# %% [markdown]
# ## Create maps for filtering out rows with identified business domain codes through vendor name. Extract subset of data
#
# After adding the manually mapped businesses, we manage to map most of the businesses to codes. Those that are still missing are dropped. The alternative would be to keep them and say that they have unknown business codes, but as those with missing matches might have some correlation with eachother this might introduce bias to the model

# %%
mask = (df['VendorName'].isin(full_map))

# %%
df_filtered = df[mask]
df_miss = df[~mask]

# %%
df_filtered.shape, df.shape, df_filtered.shape[0]/df.shape[0]
# Out:
# ((865161, 4), (880036, 4), 0.9830972823839025)

# %% [markdown]
# ## Map vendor name to business code

# %%
df_filtered['Full_code'] = df_filtered['VendorName'].map(full_map)
# Out:
# C:\Users\BJOVAS\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Save to pickle

# %%
BUSINESS_NAME_ADDITION = ''
if GET_BUSINESS_CODE:
    df = df_filtered
    BUSINESS_NAME_ADDITION = '_business'

if SCENARIO2:
    df.to_pickle(data_path + 'catalog201810_scen2' + BUSINESS_NAME_ADDITION + '.pkl')
elif SCENARIO3:
    df.to_pickle(data_path + 'catalog201810_scen3' + BUSINESS_NAME_ADDITION + '.pkl')
